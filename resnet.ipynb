# %%
import pickle
import numpy as np
import os
from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from keras.optimizers import Adam
from keras.layers import Dense,Activation,Flatten,Input,Dropout,GlobalAveragePooling2D
from keras.models import Model
from keras.utils import np_utils
import random

import matplotlib.pyplot as plt

# %%
images_dir = os.listdir("./Flicker8k_Dataset/")

images_path = './Flickr8k_Dataset/'
captions_path = './Flickr8k_text/Flickr8k.token.txt'
train_path = './Flickr8k_text/Flickr_8k.trainImages.txt'
val_path = './Flickr8k_text/Flickr_8k.devImages.txt'
test_path = './Flickr8k_text/Flickr_8k.testImages.txt'

captions = open(captions_path, 'r').read().split("\n")
x_train = open(train_path, 'r').read().split("\n")
x_val = open(val_path, 'r').read().split("\n")
x_test = x_val = open(test_path, 'r').read().split("\n")

# %%
model_test = ResNet50(include_top=False,weights='imagenet',input_shape=(224,224,3),pooling = 'avg')

# %%
model_test.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_6 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9472        input_6[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_246 (Activation)     (None, 112, 112, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 55, 55, 64)   0           activation_246[0][0]
# ...

# %%
def preprocessing(img_path):
    im = image.load_img(img_path,target_size=(224,224,3))
    im = image_img_to_array(im)
    im = np.expand_dims(im,axis=0)
    return im

# %%
train_data = {}
ctr=0
for ix in x_train:
    if ix == "":
        continue
    if ctr >= 3000:
        break
    ctr+=1
    if ctr%1000==0:
        print(ctr)
    path = images_path + ix
    img = preprocessing(path)
    pred = model.predict(img).reshape(2048)
    train_data[ix] = pred
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-b89d7f393d62> in <module>()
#      10         print(ctr)
#      11     path = images_path + ix
# ---> 12     img = preprocessing(path)
#      13     pred = model.predict(img).reshape(2048)
#      14     train_data[ix] = pred
#
# <ipython-input-24-a610be71a7cc> in preprocessing(img_path)
#       1 def preprocessing(img_path):
# ----> 2     im = image.load_img(img_path,target_size=(224,224,3))
#       3     im = image_img_to_array(im)
#       4     im = np.expand_dims(im,axis=0)
#       5     return im
#
# /usr/local/lib/python3.7/site-packages/keras/preprocessing/image.py in load_img(path, grayscale, target_size, interpolation)
#     345         raise ImportError('Could not import PIL.Image. '
#     346                           'The use of `array_to_img` requires PIL.')
# --> 347     img = pil_image.open(path)
# ...
